# %% [markdown]
# Finding so far:
# - Estimator is badly biased and the bias does not seem to be decreasing with sample size
#
# Todo
# - Check the individual estimators are consistent

# %%
# This is a first simple simulation
# %reload_ext autoreload
# %autoreload 2

from iv_part_id_estimation import *
from iv_part_id import *
from plot_funcs import *
from funcs import *
from simulate_data import *
from sim_funcs import *
from table_by_tol import *
import os

# Set seed
np.random.seed(12598612)

# %%
# Set the parameters of the model
identif = ["cross","cross","cross","cross","cross","cross"] # the set of identified estimands
basis = "cs" # the basis function to use for approximation
shape = None # shape restriction
target = "late" # the target estimand
u_lo_target = 0.35 # if target = LATE: lower u
u_hi_target = 0.9 # if target = LATE: upper u
u_part = [np.array([0, 0.35, 0.6, 0.7, 0.9, 1])] # if basis = cs: partition of u in [0,1]
supp_z = [np.array([0, 1, 2])] # if identif = iv_slope: support of the instrument
prop_z = [np.array([0.35, 0.6, 0.7])] # if identif = iv_slope: propensity given the instrument
f_z = [np.array([0.5, 0.4, 0.1])] # if identif = iv_slope: probability mass function of the instrument
dz_cross = dz_cross = [(0, 0), (0, 1), (0, 2), (1, 0), (1, 1), (1, 2)] # if identif = cross: the cross moment
m0_dgp = m0_dgp
m1_dgp = m1_dgp

# Def bld
bld = "C:/Users/budde/OneDrive/phd_bgse/courses/topics_metrics/topics_sim/bld/"

# %%
# Bounds of Figure 5
target = "late"
u_lo_target = 0.35
u_hi_target = 0.9

basis = "cs"

# Instrument
supp_z=[np.array([0, 1, 2])]
f_z=[np.array([0.5, 0.4, 0.1])]
prop_z=[np.array([0.35, 0.6, 0.7])]

# Partition of u for constant spline approximation
u_part=np.array([0, 0.35, 0.60, 0.7, 0.90, 1])

# Cross-moments
dz_cross = [(0, 0), (0, 1), (0, 2), (1, 0), (1, 1), (1, 2)]

bounds = iv_part_id(
    target, 
    identif,
    basis, 
    m0_dgp,
    m1_dgp,
    u_part = u_part, 
    u_lo_target = u_lo_target, 
    u_hi_target = u_hi_target,
    supp_z = supp_z,
    prop_z = prop_z,
    f_z = f_z,
    dz_cross = dz_cross,
    analyt_int = True,
)

beta_lo, beta_hi = bounds[0][0], bounds[1][0]
beta_lo, beta_hi
# Out:
# reset;
# set THETA;
# set IDENTIF_0;
# set IDENTIF_1;
# set IDENTIF_2;
# set IDENTIF_3;
# set IDENTIF_4;
# set IDENTIF_5;
# param gamma {THETA};
# param gamma_ident_0 {THETA};
# param val_identif_0 {IDENTIF_0};
# param gamma_ident_1 {THETA};
# param val_identif_1 {IDENTIF_1};
# param gamma_ident_2 {THETA};
# param val_identif_2 {IDENTIF_2};
# param gamma_ident_3 {THETA};
# param val_identif_3 {IDENTIF_3};
# param gamma_ident_4 {THETA};
# param val_identif_4 {IDENTIF_4};
# param gamma_ident_5 {THETA};
# param val_identif_5 {IDENTIF_5};
# var Theta_val {j in THETA} >= 0, <= 1;
# minimize beta: sum {j in THETA} gamma[j] * Theta_val[j];
# subject to Identified_0 {i in IDENTIF_0}:
# sum {j in THETA} gamma_ident_0[j] * Theta_val[j] == val_identif_0[i];
# subject to Identified_1 {i in IDENTIF_1}:
# sum {j in THETA} gamma_ident_1[j] * Theta_val[j] == val_identif_1[i];
# subject to Identified_2 {i in IDENTIF_2}:
# sum {j in THETA} gamma_ident_2[j] * Theta_val[j] == val_identif_2[i];
# ...

# %%
inpath = "C:/Users/budde/OneDrive/phd_bgse/courses/topics_metrics/topics_sim/bld/sim_parallel_20230822-102401"
outpath = "C:/Users/budde/OneDrive/phd_bgse/courses/topics_metrics/topics_sim/bld/paper/tables"

N = 10000
R = 1000
tolerances = [N**(-2), N**(-1), N**(-1/2), N**(-1/4)]

table_by_tol(inpath, outpath, N, R, tolerances, true_beta = (beta_lo, beta_hi))


inpath = "C:/Users/budde/OneDrive/phd_bgse/courses/topics_metrics/topics_sim/bld/sim_parallel_20230822-102401"
N = 1000
R = 1000
tolerances = [N**(-2), N**(-1), N**(-1/2), N**(-1/4)]

table_by_tol(inpath, outpath, N, R, tolerances, true_beta = (beta_lo, beta_hi))

inpath = "C:/Users/budde/OneDrive/phd_bgse/courses/topics_metrics/topics_sim/bld/sim_parallel_20230822-102401"

N = 25000
R = 1000
tolerances = [N**(-2), N**(-1), N**(-1/2), N**(-1/4)]

table_by_tol(inpath, outpath, N, R, tolerances, true_beta = (beta_lo, beta_hi))

# %%
# Cross-moments
dz_cross = [(0, 0), (0, 1), (0, 2)]
identif = ["cross", "cross", "cross"]

bounds = iv_part_id(
    target, 
    identif,
    basis, 
    m0_dgp,
    m1_dgp,
    u_part = u_part, 
    u_lo_target = u_lo_target, 
    u_hi_target = u_hi_target,
    supp_z = supp_z,
    prop_z = prop_z,
    f_z = f_z,
    dz_cross = dz_cross,
    analyt_int = True,
)

beta_lo, beta_hi = bounds[0][0], bounds[1][0]
beta_lo, beta_hi
# Out:
# reset;
# set THETA;
# set IDENTIF_0;
# set IDENTIF_1;
# set IDENTIF_2;
# param gamma {THETA};
# param gamma_ident_0 {THETA};
# param val_identif_0 {IDENTIF_0};
# param gamma_ident_1 {THETA};
# param val_identif_1 {IDENTIF_1};
# param gamma_ident_2 {THETA};
# param val_identif_2 {IDENTIF_2};
# var Theta_val {j in THETA} >= 0, <= 1;
# minimize beta: sum {j in THETA} gamma[j] * Theta_val[j];
# subject to Identified_0 {i in IDENTIF_0}:
# sum {j in THETA} gamma_ident_0[j] * Theta_val[j] == val_identif_0[i];
# subject to Identified_1 {i in IDENTIF_1}:
# sum {j in THETA} gamma_ident_1[j] * Theta_val[j] == val_identif_1[i];
# subject to Identified_2 {i in IDENTIF_2}:
# sum {j in THETA} gamma_ident_2[j] * Theta_val[j] == val_identif_2[i];
#
# HiGHS 1.5.1: HiGHS 1.5.1: optimal solution; objective -0.4480075758
# 0 simplex iterations
# 0 barrier iterations
# Objective is: -0.448007575757576
# argmax:           Theta_val.val
# theta0_0       0.000000
# theta0_1       0.433083
# ...

# %%
outpath = "C:/Users/budde/OneDrive/phd_bgse/courses/topics_metrics/topics_sim/bld/paper/tables/only_d0_cross"

if not os.path.exists(outpath):
    os.makedirs(outpath)

inpath = "C:/Users/budde/OneDrive/phd_bgse/courses/topics_metrics/topics_sim/bld/sim_parallel_20230822-102401"

N = 10000
R = 1000
tolerances = [N**(-2), N**(-1), N**(-1/2), N**(-1/4)]

table_by_tol(inpath, outpath, N, R, tolerances, true_beta = (beta_lo, beta_hi))


inpath = "C:/Users/budde/OneDrive/phd_bgse/courses/topics_metrics/topics_sim/bld/sim_parallel_20230822-102401"
N = 1000
R = 1000
tolerances = [N**(-2), N**(-1), N**(-1/2), N**(-1/4)]

table_by_tol(inpath, outpath, N, R, tolerances, true_beta = (beta_lo, beta_hi))

inpath = "C:/Users/budde/OneDrive/phd_bgse/courses/topics_metrics/topics_sim/bld/sim_parallel_20230822-102401"

N = 25000
R = 1000
tolerances = [N**(-2), N**(-1), N**(-1/2), N**(-1/4)]

table_by_tol(inpath, outpath, N, R, tolerances, true_beta = (beta_lo, beta_hi))

# %%
# Cross-moments
dz_cross = [(1, 0), (1, 1), (1, 2)]
identif = ["cross", "cross", "cross"]

bounds = iv_part_id(
    target, 
    identif,
    basis, 
    m0_dgp,
    m1_dgp,
    u_part = u_part, 
    u_lo_target = u_lo_target, 
    u_hi_target = u_hi_target,
    supp_z = supp_z,
    prop_z = prop_z,
    f_z = f_z,
    dz_cross = dz_cross,
    analyt_int = True,
)

beta_lo, beta_hi = bounds[0][0], bounds[1][0]
beta_lo, beta_hi
# Out:
# reset;
# set THETA;
# set IDENTIF_0;
# set IDENTIF_1;
# set IDENTIF_2;
# param gamma {THETA};
# param gamma_ident_0 {THETA};
# param val_identif_0 {IDENTIF_0};
# param gamma_ident_1 {THETA};
# param val_identif_1 {IDENTIF_1};
# param gamma_ident_2 {THETA};
# param val_identif_2 {IDENTIF_2};
# var Theta_val {j in THETA} >= 0, <= 1;
# minimize beta: sum {j in THETA} gamma[j] * Theta_val[j];
# subject to Identified_0 {i in IDENTIF_0}:
# sum {j in THETA} gamma_ident_0[j] * Theta_val[j] == val_identif_0[i];
# subject to Identified_1 {i in IDENTIF_1}:
# sum {j in THETA} gamma_ident_1[j] * Theta_val[j] == val_identif_1[i];
# subject to Identified_2 {i in IDENTIF_2}:
# sum {j in THETA} gamma_ident_2[j] * Theta_val[j] == val_identif_2[i];
#
# HiGHS 1.5.1: HiGHS 1.5.1: optimal solution; objective -0.6897727263
# 0 simplex iterations
# 0 barrier iterations
# Objective is: -0.6897727262703295
# argmax:           Theta_val.val
# theta0_0         0.0000
# theta0_1         1.0000
# ...

# %%
outpath = "C:/Users/budde/OneDrive/phd_bgse/courses/topics_metrics/topics_sim/bld/paper/tables/only_d1_cross"

if not os.path.exists(outpath):
    os.makedirs(outpath)

inpath = "C:/Users/budde/OneDrive/phd_bgse/courses/topics_metrics/topics_sim/bld/sim_parallel_20230822-102401"

N = 1000
R = 1000
tolerances = [N**(-2), N**(-1), N**(-1/2), N**(-1/4)]

table_by_tol(inpath, outpath, N, R, tolerances, true_beta = (beta_lo, beta_hi))


inpath = "C:/Users/budde/OneDrive/phd_bgse/courses/topics_metrics/topics_sim/bld/sim_parallel_20230822-102401"
N = 10000
R = 1000
tolerances = [N**(-2), N**(-1), N**(-1/2), N**(-1/4)]

table_by_tol(inpath, outpath, N, R, tolerances, true_beta = (beta_lo, beta_hi))

inpath = "C:/Users/budde/OneDrive/phd_bgse/courses/topics_metrics/topics_sim/bld/sim_parallel_20230822-102401"

N = 25000
R = 1000
tolerances = [N**(-2), N**(-1), N**(-1/2), N**(-1/4)]

table_by_tol(inpath, outpath, N, R, tolerances, true_beta = (beta_lo, beta_hi))

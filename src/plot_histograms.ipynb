# %%
# Notebook to create the histograms in the paper
# %reload_ext autoreload
# %autoreload 2
from simulation_sharp_bounds import *
import numpy as np
from scipy.stats import norm
from plot_histograms import plot_histograms

# Simulation using the adjusted target parameter (taking estimated propensity
# score instead of 0.35 for the lower ound)
simpar_dir1 = "sim_parallel_20230827-114636"
simpar_dir2 = "sim_parallel_20230827-144526"

results1 = "C:/Users/budde/OneDrive/phd_bgse/courses/topics_metrics/topics_sim/bld/" + simpar_dir1 +"/"
results2 = "C:/Users/budde/OneDrive/phd_bgse/courses/topics_metrics/topics_sim/bld/" + simpar_dir2 +"/"
graph = "C:/Users/budde/OneDrive/phd_bgse/courses/topics_metrics/topics_sim/bld/paper/graph/"

# %%
filelo = "beta_lo_n10000_r500_tol0.0001_lo0.35_hi0.9000000000000005.npy" 
filehi = "beta_hi_n10000_r500_tol0.0001_lo0.35_hi0.9000000000000005.npy" 

plot_histograms(filelo, filehi, results1, graph, separate=True)
# Out:
# reset;
# set THETA;
# set IDENTIF_0;
# set IDENTIF_1;
# set IDENTIF_2;
# set IDENTIF_3;
# set IDENTIF_4;
# set IDENTIF_5;
# param gamma {THETA};
# param gamma_ident_0 {THETA};
# param val_identif_0 {IDENTIF_0};
# param gamma_ident_1 {THETA};
# param val_identif_1 {IDENTIF_1};
# param gamma_ident_2 {THETA};
# param val_identif_2 {IDENTIF_2};
# param gamma_ident_3 {THETA};
# param val_identif_3 {IDENTIF_3};
# param gamma_ident_4 {THETA};
# param val_identif_4 {IDENTIF_4};
# param gamma_ident_5 {THETA};
# param val_identif_5 {IDENTIF_5};
# var Theta_val {j in THETA} >= 0, <= 1;
# minimize beta: sum {j in THETA} gamma[j] * Theta_val[j];
# subject to Identified_0 {i in IDENTIF_0}:
# sum {j in THETA} gamma_ident_0[j] * Theta_val[j] == val_identif_0[i];
# subject to Identified_1 {i in IDENTIF_1}:
# sum {j in THETA} gamma_ident_1[j] * Theta_val[j] == val_identif_1[i];
# subject to Identified_2 {i in IDENTIF_2}:
# sum {j in THETA} gamma_ident_2[j] * Theta_val[j] == val_identif_2[i];
# ...

# %%
filelo = "beta_lo_n25000_r500_tol4e-05_lo0.35_hi0.9000000000000005.npy" 
filehi = "beta_hi_n25000_r500_tol4e-05_lo0.35_hi0.9000000000000005.npy" 
plot_histograms(filelo, filehi, results2, graph, separate=True)
# Out:
# reset;
# set THETA;
# set IDENTIF_0;
# set IDENTIF_1;
# set IDENTIF_2;
# set IDENTIF_3;
# set IDENTIF_4;
# set IDENTIF_5;
# param gamma {THETA};
# param gamma_ident_0 {THETA};
# param val_identif_0 {IDENTIF_0};
# param gamma_ident_1 {THETA};
# param val_identif_1 {IDENTIF_1};
# param gamma_ident_2 {THETA};
# param val_identif_2 {IDENTIF_2};
# param gamma_ident_3 {THETA};
# param val_identif_3 {IDENTIF_3};
# param gamma_ident_4 {THETA};
# param val_identif_4 {IDENTIF_4};
# param gamma_ident_5 {THETA};
# param val_identif_5 {IDENTIF_5};
# var Theta_val {j in THETA} >= 0, <= 1;
# minimize beta: sum {j in THETA} gamma[j] * Theta_val[j];
# subject to Identified_0 {i in IDENTIF_0}:
# sum {j in THETA} gamma_ident_0[j] * Theta_val[j] == val_identif_0[i];
# subject to Identified_1 {i in IDENTIF_1}:
# sum {j in THETA} gamma_ident_1[j] * Theta_val[j] == val_identif_1[i];
# subject to Identified_2 {i in IDENTIF_2}:
# sum {j in THETA} gamma_ident_2[j] * Theta_val[j] == val_identif_2[i];
# ...

# %%
filelo = "beta_lo_n50000_r500_tol4e-05_lo0.35_hi0.9000000000000005.npy" 
filehi = "beta_hi_n50000_r500_tol4e-05_lo0.35_hi0.9000000000000005.npy" 
plot_histograms(filelo, filehi, results2, graph, separate=True)
# Out:
# reset;
# set THETA;
# set IDENTIF_0;
# set IDENTIF_1;
# set IDENTIF_2;
# set IDENTIF_3;
# set IDENTIF_4;
# set IDENTIF_5;
# param gamma {THETA};
# param gamma_ident_0 {THETA};
# param val_identif_0 {IDENTIF_0};
# param gamma_ident_1 {THETA};
# param val_identif_1 {IDENTIF_1};
# param gamma_ident_2 {THETA};
# param val_identif_2 {IDENTIF_2};
# param gamma_ident_3 {THETA};
# param val_identif_3 {IDENTIF_3};
# param gamma_ident_4 {THETA};
# param val_identif_4 {IDENTIF_4};
# param gamma_ident_5 {THETA};
# param val_identif_5 {IDENTIF_5};
# var Theta_val {j in THETA} >= 0, <= 1;
# minimize beta: sum {j in THETA} gamma[j] * Theta_val[j];
# subject to Identified_0 {i in IDENTIF_0}:
# sum {j in THETA} gamma_ident_0[j] * Theta_val[j] == val_identif_0[i];
# subject to Identified_1 {i in IDENTIF_1}:
# sum {j in THETA} gamma_ident_1[j] * Theta_val[j] == val_identif_1[i];
# subject to Identified_2 {i in IDENTIF_2}:
# sum {j in THETA} gamma_ident_2[j] * Theta_val[j] == val_identif_2[i];
# ...
